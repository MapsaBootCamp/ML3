# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data_for_clustering.csv", header=None)
plt.scatter(df.iloc[:, 0], df.iloc[:, 1])

# %%
X = df.values

# %%
from sklearn.cluster import KMeans

k = 2
colors = ["red", "blue"]
km = KMeans(n_clusters=k)
km.fit(X)
# Out:
# /Users/teghfo/Desktop/ML3/venv/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=2)

# %%
for cl in range(k):
    plt.scatter(X[km.labels_ == cl, 0], X[km.labels_ == cl, 1], color=colors[cl])
plt.scatter(km.cluster_centers_[:, 0], km.cluster_centers_[:, 1], color="black")

# %%
from sklearn.cluster import DBSCAN

# %%
eps = 0.5
min_samples = 5

dbscan = DBSCAN(eps=eps, min_samples = min_samples)
dbscan.fit(X)
# Out:
# DBSCAN()

# %%
cluster_dbscan = list(set(dbscan.labels_))

# %%
for cl in cluster_dbscan:
    plt.scatter(X[dbscan.labels_ == cl, 0], X[dbscan.labels_ == cl, 1])
plt.scatter(X[dbscan.labels_ == -1, 0], X[dbscan.labels_ == -1, 1], color="black")

# %%
from sklearn.metrics import davies_bouldin_score

davies_bouldin_score(X, dbscan.labels_)
# Out:
# 2.688141436728507
