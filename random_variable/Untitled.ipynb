# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
car_df = pd.read_csv("car.csv")
car_df.columns = ["min", "sec"]
car_df
# Out:
#      min  sec
# 0      0    0
# 1      0    1
# 2      0    2
# 3      0    3
# 4      0    3
# ..   ...  ...
# 346    9   54
# 347    9   55
# 348    9   55
# 349    9   58
# 350    9   59
#
# [351 rows x 2 columns]

# %%
car_df.groupby("min").count()["sec"].mean()
# lamda = len(car_df) / 10
# Out:
# 35.1

# %%
sns.distplot(np.random.poisson(35.1, 400))
# Out:
# /tmp/ipykernel_29047/4018581268.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.random.poisson(35.1, 400))
# <AxesSubplot: ylabel='Density'>

# %%
sns.distplot(np.random.normal(3, 1, 400))
# Out:
# /tmp/ipykernel_29047/1406727240.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.random.normal(3, 1, 400))
# <AxesSubplot: ylabel='Density'>

# %%
users = ["Ashkan", "Ghasem", "Ali"]

np.random.choice(users, p=[0.7, 0, 0.3], size=20)
# Out:
# array(['Ashkan', 'Ashkan', 'Ali', 'Ashkan', 'Ashkan', 'Ashkan', 'Ashkan',
#        'Ashkan', 'Ashkan', 'Ashkan', 'Ali', 'Ali', 'Ali', 'Ashkan',
#        'Ashkan', 'Ashkan', 'Ashkan', 'Ashkan', 'Ali', 'Ali'], dtype='<U6')
