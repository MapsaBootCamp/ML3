# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
years = [2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
GDP = [226.45, 266.30, 349.88, 412.34, 416.40, 486.81, 580.76, 598.87, 460.29, 432.69, 384.95, 417.98, 445.35, 446.105, 463, 410.00]

# %% [markdown]
# ### plt.plot(x , y , color = '', marker = '', linestyle = '')

# %%
plt.figure(figsize=(10, 2))
plt.plot(years, GDP, color = 'green' , marker = '*',linestyle = '-')

# %%
# Reference : Data Science from Scratch Book


variance = [1, 2, 4, 8, 16, 32, 64, 128, 256]
bias_squared = [256, 128, 64, 32, 16, 8, 4, 2, 1]
total_error = [x + y for x, y in zip(variance, bias_squared)]
xs = [i for i, _ in enumerate(variance)]

# %%
plt.figure(figsize=(6, 2))

plt.plot(xs, variance, 'g-', label='variance') # green solid line
plt.plot(xs, bias_squared, 'r-.', label='bias^2') # red dot-dashed line
plt.plot(xs, total_error, 'b:', label='total error') # blue dotted line
# Because we've assigned labels to each series,
# we can get a legend for free (loc=9 means "top center")
plt.legend(loc=0)
plt.xlabel("model complexity")
plt.ylabel("val")

plt.xticks(range(0, 8, 2))
# plt.yticks(bias_squareds_squared)
plt.title("The Bias-Variance Tradeoff")
plt.show()

# %%
iris_df = pd.read_csv('iris.csv')

# %%
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width   class
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
plt.figure(figsize=(5, 6))

counter = 1
for elm in iris_df.columns[:-1]:
    plt.subplot(220+counter)
    plt.hist(iris_df[elm])
    plt.title(elm)
    counter += 1

# plt.subplot(221)
# plt.hist(iris_df['petal_length'])
# plt.subplot()

# %%
new_sepal_less = iris_df[iris_df['sepal_length'] < 4.5 ]['sepal_length']
new_sepal_bet = iris_df[(4.5 <= iris_df['sepal_length']) & (iris_df['sepal_length'] < 5) ]['sepal_length']
new_sepal_mor = iris_df[iris_df['sepal_length'] >= 5 ]['sepal_length']

# %%
X = iris_df['sepal_length']
y = iris_df['sepal_width']

plt.figure(figsize=(10, 10))


plt.subplot(231)
plt.scatter(X, y)
plt.xlabel('sepal_length')
plt.ylabel('sepal_width')

plt.title('sepal l vs sepal w')




plt.subplot(232)
plt.hist(new_sepal_less, bins=50)
plt.xlabel('val')
plt.ylabel('count')

plt.title('sepal less than 4.5')



plt.subplot(233)
plt.hist(new_sepal_bet, bins=20)
plt.xlabel('val')
plt.ylabel('count')

plt.title('sepal between 4.5 and 5')


plt.subplot(234)
plt.hist(new_sepal_mor, bins=20)
plt.xlabel('val')
plt.ylabel('count')

plt.title('sepal more than 5')
# Out:
# Text(0.5, 1.0, 'sepal more than 5')

# %%
X = iris_df['sepal_length']
y = iris_df['sepal_width']

plt.figure(figsize=(9,40))


plt.subplot2grid((10,2),(3,1))
plt.scatter(X, y)
plt.xlabel('sepal_length')
plt.ylabel('sepal_width')

plt.title('sepal l vs sepal w')




plt.subplot2grid((10,2),(7,1))
plt.hist(new_sepal_less, bins=50)
plt.xlabel('val')
plt.ylabel('count')

plt.title('sepal less than 4.5')



plt.subplot2grid((10,2),(9,1))
plt.hist(new_sepal_bet, bins=20)
plt.xlabel('val')
plt.ylabel('count')

plt.title('sepal between 4.5 and 5')


plt.subplot2grid((10,2),(5,0))
plt.hist(new_sepal_mor, bins=20)
plt.xlabel('val')
plt.ylabel('count')

plt.title('sepal more than 5')
# Out:
# Text(0.5, 1.0, 'sepal more than 5')

# %%
plt.hist(iris_df['sepal_length'], bins=20)
# Out:
# (array([ 4.,  5.,  7., 16.,  9.,  5., 13., 14., 10.,  6., 10., 16.,  7.,
#         11.,  4.,  2.,  4.,  1.,  5.,  1.]),
#  array([4.3 , 4.48, 4.66, 4.84, 5.02, 5.2 , 5.38, 5.56, 5.74, 5.92, 6.1 ,
#         6.28, 6.46, 6.64, 6.82, 7.  , 7.18, 7.36, 7.54, 7.72, 7.9 ]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(iris_df['sepal_width'], bins=30)
# Out:
# (array([ 1.,  0.,  3.,  4.,  0.,  3.,  8.,  5.,  9., 14.,  0., 10., 26.,
#         12.,  0., 13.,  6., 12.,  6.,  3.,  0.,  3.,  6.,  2.,  0.,  1.,
#          1.,  1.,  0.,  1.]),
#  array([2.  , 2.08, 2.16, 2.24, 2.32, 2.4 , 2.48, 2.56, 2.64, 2.72, 2.8 ,
#         2.88, 2.96, 3.04, 3.12, 3.2 , 3.28, 3.36, 3.44, 3.52, 3.6 , 3.68,
#         3.76, 3.84, 3.92, 4.  , 4.08, 4.16, 4.24, 4.32, 4.4 ]),
#  <a list of 30 Patch objects>)

# %%
# plt.boxplot(iris_df.iloc[:, :4])
# plt.show()


iris_df.iloc[:, :4]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
pd.melt(iris_df, id_vars=['sepal_length'], value_vars='class')
# Out:
#      sepal_length variable      value
# 0             5.1    class     setosa
# 1             4.9    class     setosa
# 2             4.7    class     setosa
# 3             4.6    class     setosa
# 4             5.0    class     setosa
# ..            ...      ...        ...
# 145           6.7    class  virginica
# 146           6.3    class  virginica
# 147           6.5    class  virginica
# 148           6.2    class  virginica
# 149           5.9    class  virginica
#
# [150 rows x 3 columns]

# %%
spread = np.random.rand(50) * 100
center = np.ones(25) * 40
flier_high = np.random.rand(10) * 100 + 100
flier_low = np.random.rand(10) * -100
d2 = np.concatenate((spread, center, flier_high, flier_low))
data = np.concatenate((spread, center, flier_high, flier_low))
data.shape = (-1, 1)
d2.shape = (-1, 1)

# %%
class_ = list(set(iris_df['class']))


iris_list = []
for i in class_:
    print(i)
    iris_list.append(iris_df['sepal_length'][iris_df['class']==i].tolist())
    
# [iris_df['sepal_length'][iris_df['class']==i].tolist() for i in class_]
plt.figure()
plt.boxplot(iris_list, labels=class_)
    

# plt.boxplot(y)
# Out:
# virginica
# setosa
# versicolor
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fc679e07d00>,
#   <matplotlib.lines.Line2D at 0x7fc679e07fa0>,
#   <matplotlib.lines.Line2D at 0x7fc679da2fd0>,
#   <matplotlib.lines.Line2D at 0x7fc679daf2b0>,
#   <matplotlib.lines.Line2D at 0x7fc67ab0ef40>,
#   <matplotlib.lines.Line2D at 0x7fc67ad3d730>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fc679da2280>,
#   <matplotlib.lines.Line2D at 0x7fc679da2520>,
#   <matplotlib.lines.Line2D at 0x7fc679daf550>,
#   <matplotlib.lines.Line2D at 0x7fc679daf7f0>,
#   <matplotlib.lines.Line2D at 0x7fc67ab14f10>,
#   <matplotlib.lines.Line2D at 0x7fc679dab0a0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fc679e07a60>,
#   <matplotlib.lines.Line2D at 0x7fc679da2d30>,
#   <matplotlib.lines.Line2D at 0x7fc679daffd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fc679da27c0>,
#   <matplotlib.lines.Line2D at 0x7fc679dafa90>,
#   <matplotlib.lines.Line2D at 0x7fc679dab340>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fc679da2a60>,
#   <matplotlib.lines.Line2D at 0x7fc679dafd30>,
#   <matplotlib.lines.Line2D at 0x7fc679dab5e0>],
#  'means': []}

# %%
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width   class
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
plt.figure(figsize=(6, 4))
plt.title("setal_length vs setal_width")

color_plt = {class_[0] : 'red', class_[1] : 'green', class_[2]: 'blue'}


for val in class_:
    
    temp = iris_df[iris_df['class'] == val]
    # plt.scatter(temp['petal_length'], temp['petal_width'], c= color_plt[val] , label=val)
    plt.scatter(temp['sepal_length'], temp['sepal_width'], c= color_plt[val] , label=val)

    
plt.legend()
plt.xlabel('setal_length')
plt.ylabel('setal_width')
plt.show()

# %%
my_list = [3 , 5 , 7]

for index, val in enumerate(my_list):
    print('index: ', index)
    print('val: ', val)
# Out:
# index:  0
# val:  3
# index:  1
# val:  5
# index:  2
# val:  7

# %%
# TODO dataset titanic , plot

# %%
uniform_random = np.random.uniform(0,10,10000)

# %%
plt.hist(uniform_random, bins=10)
# Out:
# (array([ 980., 1005.,  963.,  938., 1044.,  996., 1021., 1029.,  982.,
#         1042.]),
#  array([2.27367713e-05, 9.99776187e-01, 1.99952964e+00, 2.99928309e+00,
#         3.99903654e+00, 4.99878999e+00, 5.99854344e+00, 6.99829689e+00,
#         7.99805034e+00, 8.99780379e+00, 9.99755724e+00]),
#  <BarContainer object of 10 artists>)

# %%
normal_random = 2 * np.random.randn(1000) + 5

# %%
plt.hist(normal_random, bins=50)
# Out:
# (array([ 1.,  1.,  1.,  2.,  1.,  6.,  2.,  5.,  4.,  7., 12.,  9., 18.,
#         16., 20., 27., 37., 21., 30., 37., 41., 47., 63., 53., 57., 38.,
#         51., 34., 32., 51., 27., 41., 40., 36., 28., 27., 17., 15.,  8.,
#         12., 10.,  6.,  2.,  0.,  1.,  3.,  0.,  1.,  1.,  1.]),
#  array([-1.19298241, -0.94775363, -0.70252484, -0.45729605, -0.21206726,
#          0.03316153,  0.27839032,  0.5236191 ,  0.76884789,  1.01407668,
#          1.25930547,  1.50453426,  1.74976304,  1.99499183,  2.24022062,
#          2.48544941,  2.7306782 ,  2.97590699,  3.22113577,  3.46636456,
#          3.71159335,  3.95682214,  4.20205093,  4.44727972,  4.6925085 ,
#          4.93773729,  5.18296608,  5.42819487,  5.67342366,  5.91865245,
#          6.16388123,  6.40911002,  6.65433881,  6.8995676 ,  7.14479639,
#          7.39002518,  7.63525396,  7.88048275,  8.12571154,  8.37094033,
#          8.61616912,  8.86139791,  9.10662669,  9.35185548,  9.59708427,
#          9.84231306, 10.08754185, 10.33277064, 10.57799942, 10.82322821,
#         11.068457  ]),
#  <BarContainer object of 50 artists>)

# %%
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width   class
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
fig = sns.displot(uniform_random,bins=100, kde=True)
fig.set(xlabel = "uniform dist", ylabel="frequency")

# %%
sns.kdeplot(normal_random, cmap="mako")

# %%
plt.figure(figsize=(9,10))

plt.subplot(2, 2, (1, 1))
plt.hist(iris_df["sepal_length"], bins=30)
plt.xlabel("sepal_length")
plt.ylabel("frequency")


plt.subplot(222)
plt.hist(iris_df["sepal_width"], bins=30)
plt.xlabel("sepal_width")
plt.ylabel("frequency")


plt.subplot(223)
plt.hist(iris_df["petal_length"], bins=30)
plt.xlabel("petal_length")
plt.ylabel("frequency")


plt.subplot(224)
plt.hist(iris_df["petal_width"], bins=30)
plt.xlabel("petal_width")
plt.ylabel("frequency")

plt.show()

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   class         150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris_df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
X = np.arange(0, 8, 0.01)
y = 10 * np.sin(np.pi * X)
white_noise = np.random.randn(len(y))
plt.plot(X, y + white_noise, color="r")
plt.plot(X, y)
plt.show()
